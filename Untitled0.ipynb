# %%
pip install -U git+https://github.com/PrithivirajDamodaran/Gramformer.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/PrithivirajDamodaran/Gramformer.git
#   Cloning https://github.com/PrithivirajDamodaran/Gramformer.git to /private/var/folders/2r/bmy2ygwd5bjbl56ghmbjmcnc0000gn/T/pip-req-build-esyhtwuq
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Gramformer.git /private/var/folders/2r/bmy2ygwd5bjbl56ghmbjmcnc0000gn/T/pip-req-build-esyhtwuq
#   Resolved https://github.com/PrithivirajDamodaran/Gramformer.git to commit 23425cd2e98a919384cab6156af8adf1c9d0639a
# Requirement already satisfied: transformers in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (4.35.2)
# Requirement already satisfied: sentencepiece in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (0.1.99)
# Requirement already satisfied: python-Levenshtein in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (0.23.0)
# Requirement already satisfied: fuzzywuzzy in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (0.18.0)
# Requirement already satisfied: tokenizers in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (0.15.0)
# Requirement already satisfied: fsspec in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (2023.10.0)
# Requirement already satisfied: errant in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from gramformer==1.0) (3.0.0)
# Requirement already satisfied: rapidfuzz>=3.4.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from errant->gramformer==1.0) (3.5.2)
# Requirement already satisfied: spacy<4,>=3.2.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from errant->gramformer==1.0) (3.7.2)
# Requirement already satisfied: packaging>=20.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (23.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (1.26.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (2.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (1.0.10)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (58.0.4)
# Requirement already satisfied: jinja2 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (3.1.2)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (8.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (2.5.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (2.4.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (4.66.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (3.0.9)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (0.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (2.31.0)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from spacy<4,>=3.2.0->errant->gramformer==1.0) (6.4.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4,>=3.2.0->errant->gramformer==1.0) (4.8.0)
# Requirement already satisfied: pydantic-core==2.14.3 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4,>=3.2.0->errant->gramformer==1.0) (2.14.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4,>=3.2.0->errant->gramformer==1.0) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<4,>=3.2.0->errant->gramformer==1.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<4,>=3.2.0->errant->gramformer==1.0) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<4,>=3.2.0->errant->gramformer==1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy<4,>=3.2.0->errant->gramformer==1.0) (2023.11.17)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4,>=3.2.0->errant->gramformer==1.0) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4,>=3.2.0->errant->gramformer==1.0) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from typer<0.10.0,>=0.3.0->spacy<4,>=3.2.0->errant->gramformer==1.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4,>=3.2.0->errant->gramformer==1.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy<4,>=3.2.0->errant->gramformer==1.0) (2.1.3)
# Requirement already satisfied: Levenshtein==0.23.0 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from python-Levenshtein->gramformer==1.0) (0.23.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from tokenizers->gramformer==1.0) (0.19.4)
# Requirement already satisfied: filelock in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->gramformer==1.0) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->gramformer==1.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from transformers->gramformer==1.0) (2023.10.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/akhilsai/Library/Python/3.9/lib/python/site-packages (from transformers->gramformer==1.0) (0.4.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.datasets import Multi30k

import numpy as np
import spacy
import random
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/akhilsai/Downloads/Untitled0.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/akhilsai/Downloads/Untitled0.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import torch
#       <a href='vscode-notebook-cell:/Users/akhilsai/Downloads/Untitled0.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import torch.nn as nn
#       <a href='vscode-notebook-cell:/Users/akhilsai/Downloads/Untitled0.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'

# %%
class Gramformer:

  def __init__(self, models=1, use_gpu=False):
    from transformers import AutoTokenizer
    from transformers import AutoModelForSeq2SeqLM
    #from lm_scorer.models.auto import AutoLMScorer as LMScorer
    import errant
    self.annotator = errant.load('en')

    if use_gpu:
        device= "cuda:0"
    else:
        device = "cpu"
    batch_size = 1
    #self.scorer = LMScorer.from_pretrained("gpt2", device=device, batch_size=batch_size)
    self.device    = device
    correction_model_tag = "prithivida/grammar_error_correcter_v1"
    self.model_loaded = False

    if models == 1:
        self.correction_tokenizer = AutoTokenizer.from_pretrained(correction_model_tag, use_auth_token=False)
        self.correction_model     = AutoModelForSeq2SeqLM.from_pretrained(correction_model_tag, use_auth_token=False)
        self.correction_model     = self.correction_model.to(device)
        self.model_loaded = True
        print("[Gramformer] Grammar error correct/highlight model loaded..")
    elif models == 2:
        # TODO
        print("TO BE IMPLEMENTED!!!")

  def correct(self, input_sentence, max_candidates=1):
      if self.model_loaded:
        correction_prefix = "gec: "
        input_sentence = correction_prefix + input_sentence
        input_ids = self.correction_tokenizer.encode(input_sentence, return_tensors='pt')
        input_ids = input_ids.to(self.device)

        preds = self.correction_model.generate(
            input_ids,
            do_sample=True,
            max_length=128,
#             top_k=50,
#             top_p=0.95,
            num_beams=7,
            early_stopping=True,
            num_return_sequences=max_candidates)

        corrected = set()
        for pred in preds:
          corrected.add(self.correction_tokenizer.decode(pred, skip_special_tokens=True).strip())

        #corrected = list(corrected)
        #scores = self.scorer.sentence_score(corrected, log=True)
        #ranked_corrected = [(c,s) for c, s in zip(corrected, scores)]
        #ranked_corrected.sort(key = lambda x:x[1], reverse=True)
        return corrected
      else:
        print("Model is not loaded")
        return None

  def highlight(self, orig, cor):
      edits = self._get_edits(orig, cor)
      orig_tokens = orig.split()

      ignore_indexes = []

      for edit in edits:
          edit_type = edit[0]
          edit_str_start = edit[1]
          edit_spos = edit[2]
          edit_epos = edit[3]
          edit_str_end = edit[4]

          # if no_of_tokens(edit_str_start) > 1 ==> excluding the first token, mark all other tokens for deletion
          for i in range(edit_spos+1, edit_epos):
            ignore_indexes.append(i)

          if edit_str_start == "":
              if edit_spos - 1 >= 0:
                  new_edit_str = orig_tokens[edit_spos - 1]
                  edit_spos -= 1
              else:
                  new_edit_str = orig_tokens[edit_spos + 1]
                  edit_spos += 1
              if edit_type == "PUNCT":
                st = "<a type='" + edit_type + "' edit='" + \
                    edit_str_end + "'>" + new_edit_str + "</a>"
              else:
                st = "<a type='" + edit_type + "' edit='" + new_edit_str + \
                    " " + edit_str_end + "'>" + new_edit_str + "</a>"
              orig_tokens[edit_spos] = st
          elif edit_str_end == "":
            st = "<d type='" + edit_type + "' edit=''>" + edit_str_start + "</d>"
            orig_tokens[edit_spos] = st
          else:
            st = "<c type='" + edit_type + "' edit='" + \
                edit_str_end + "'>" + edit_str_start + "</c>"
            orig_tokens[edit_spos] = st

      for i in sorted(ignore_indexes, reverse=True):
        del(orig_tokens[i])

      return(" ".join(orig_tokens))

  def detect(self, input_sentence):
        # TO BE IMPLEMENTED
        pass

  def _get_edits(self, orig, cor):
        orig = self.annotator.parse(orig)
        cor = self.annotator.parse(cor)
        alignment = self.annotator.align(orig, cor)
        edits = self.annotator.merge(alignment)

        if len(edits) == 0:
            return []

        edit_annotations = []
        for e in edits:
            e = self.annotator.classify(e)
            edit_annotations.append((e.type[2:], e.o_str, e.o_start, e.o_end,  e.c_str, e.c_start, e.c_end))

        if len(edit_annotations) > 0:
            return edit_annotations
        else:
            return []

  def get_edits(self, orig, cor):
      return self._get_edits(orig, cor)

# %%
from gramformer import Gramformer
import torch

def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(1212)


gf = Gramformer(models = 1, use_gpu=False) # 1=corrector, 2=detector

influent_sentences = [
    "He are moving here.",
    "I am doing fine. How is you?",
    "How is they?",
    "Matt like fish",
    "the collection of letters was original used by the ancient Romans",
    "We enjoys horror movies",
    "Anna and Mike is going skiing",
    "I walk to the store and I bought milk",
    " We all eat the fish and then made dessert",
    "I will eat fish for dinner and drink milk",
    "what be the reason for everyone leave the company",
]

for influent_sentence in influent_sentences:
    corrected_sentences = gf.correct(influent_sentence, max_candidates=1)
    print("[Input] ", influent_sentence)
    for corrected_sentence in corrected_sentences:
      print("[Correction] ",corrected_sentence)
    print("-" *100)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:671: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# [Gramformer] Grammar error correct/highlight model loaded..
# [Input]  He are moving here.
# [Correction]  He is moving here.
# ----------------------------------------------------------------------------------------------------
# [Input]  I am doing fine. How is you?
# [Correction]  I am doing fine. How are you?
# ----------------------------------------------------------------------------------------------------
# [Input]  How is they?
# [Correction]  How are they?
# ----------------------------------------------------------------------------------------------------
# [Input]  Matt like fish
# [Correction]  Matt likes fish.
# ----------------------------------------------------------------------------------------------------
# [Input]  the collection of letters was original used by the ancient Romans
# [Correction]  the collection of letters was originally used by the ancient Romans
# ----------------------------------------------------------------------------------------------------
# [Input]  We enjoys horror movies
# [Correction]  We enjoy horror movies.
# ----------------------------------------------------------------------------------------------------
# [Input]  Anna and Mike is going skiing
# [Correction]  Anna and Mike are going skiing.
# ----------------------------------------------------------------------------------------------------
# [Input]  I walk to the store and I bought milk
# [Correction]  I walked to the store and I bought milk.
# ----------------------------------------------------------------------------------------------------
# [Input]   We all eat the fish and then made dessert
# [Correction]  We all ate the fish and then made dessert.
# ----------------------------------------------------------------------------------------------------
# [Input]  I will eat fish for dinner and drink milk
# [Correction]  I will eat fish for dinner and drink milk.
# ----------------------------------------------------------------------------------------------------
# [Input]  what be the reason for everyone leave the company
# [Correction]  what is the reason for everyone leaving the company?
# ----------------------------------------------------------------------------------------------------
